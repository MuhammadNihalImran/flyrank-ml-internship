# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MuhammadNihalImran/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ###My Lane
#
# Search Ranking & Content Performance Prediction
#
# ###Why I Chose This Lane
#
# I chose this lane because businesses rely on search performance to attract users and customers. Predicting which content performs better can help teams optimize their content strategy and improve visibility. This problem is practical, data-driven, and aligns with my goal of becoming a Machine Learning Engineer

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Research Question**
#
# Can machine learning predict which content is likely to achieve better search performance based on historical search data?
#
# Decision
# **bold text**
# Decide which content should be prioritized for optimization.
#
# **Action**
#
# Optimize or update high-potential content before publishing or improve underperforming pages.
#
# **Cost of a Wrong Recommendation**
#
# If the prediction is incorrect, teams may spend time and resources improving the wrong content while missing opportunities to improve better-performing pages.
#
# **Why Machine Learning Helps**
#
# Machine Learning can identify hidden patterns in historical search data that are difficult to detect manually, leading to more informed content optimization decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# **I Can Claim**
# This research explores patterns in historical search data.
# Machine learning may help improve content optimization decisions.
# Results will be evaluated using measurable performance metrics.
#
#
# **I Cannot Claim**
# The model will always predict search performance correctly.
# The results guarantee higher rankings.
# The findings apply to every website or dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# ✅ I selected one research lane.
# ✅ I clearly defined the research question.
# ✅ I identified the decision.
# ✅ I identified the action.
# ✅ I explained the cost of a wrong decision.
# ✅ I included real numbers from the starter dataset.
# ✅ I avoided making unrealistic claims.
